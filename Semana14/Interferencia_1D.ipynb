# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/FisicaA/blob/main/Semana14/Interferencia_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

x = np.linspace(0, 10, 500)

k = 2.0
omega = 2.0
t = 0.0

phi = np.pi / 2

u1 = np.cos(k*x - omega*t)
u2 = np.cos(k*x - omega*t + phi)

u = u1 + u2

plt.plot(x, u1, label="u1")
plt.plot(x, u2, label="u2")
plt.plot(x, u, label="suma", linewidth=2)

plt.xlabel("x")
plt.ylabel("u")
plt.title("Interferencia en 1D")
plt.legend()

plt.savefig("Interferencia_1D.pdf", dpi=300, bbox_inches="tight")
plt.show()

files.download("Interferencia_1D.pdf")
