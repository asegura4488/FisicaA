# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/FisicaA/blob/main/Semana14/Interferencia_1D_Fases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# =====================================================
# INTERFERENCIA 1D PARA DIFERENTES FASES
# =====================================================

x = np.linspace(0, 10, 500)

k = 2.0
omega = 2.0
t = 0.0

fases = [0, np.pi/2, np.pi]

plt.figure(figsize=(8,5))

for phi in fases:
    u = np.cos(k*x - omega*t) + np.cos(k*x - omega*t + phi)
    plt.plot(x, u, label=f"phi={round(phi,2)}")

plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.title("Interferencia para diferentes fases")
plt.legend()

plt.tight_layout()
plt.savefig("Interferencia_1D_Fases.pdf", dpi=300, bbox_inches="tight")
plt.show()

files.download("Interferencia_1D_Fases.pdf")
