# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/FisicaA/blob/main/Semana1/Lab_Ajuste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# =====================================================
# LEER DATOS DESDE LA CARPETA
# =====================================================

carpeta = "/content/drive/MyDrive/Datos_Lab1"
archivo = "datos_parabola.csv"

ruta = os.path.join(carpeta, archivo)

df = pd.read_csv(ruta)

x = df["x"].values
y = df["y"].values

# =====================================================
# AJUSTE CUADRATICO
# =====================================================

coef = np.polyfit(x, y, 2)
a, b, c = coef

print("Coeficientes del ajuste:")
print(f"a = {a:.4f}")
print(f"b = {b:.4f}")
print(f"c = {c:.4f}")

# =====================================================
# GRAFICA
# =====================================================

x_fit = np.linspace(min(x), max(x), 200)
y_fit = a*x_fit**2 + b*x_fit + c

plt.figure(figsize=(6,5))
plt.scatter(x, y, color='k' ,label="Datos experimentales")
plt.plot(x_fit, y_fit, color='r' ,label="Ajuste cuadrático", linewidth=2)

plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste parabólico desde archivo CSV")
plt.legend()

# Guardar en la misma carpeta
ruta_fig = os.path.join(carpeta, "Ajuste_Parabola.pdf")
plt.savefig(ruta_fig, dpi=300, bbox_inches="tight")

plt.show()

# Descargar figura
files.download(ruta_fig)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Coeficientes del ajuste:
# a = 1.9817
# b = 2.9144
# c = 1.6200

# %%
# Out:
# sample_data
