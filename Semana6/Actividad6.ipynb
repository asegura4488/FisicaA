# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/FisicaA/blob/main/Semana6/Actividad6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# -----------------------------
# Parámetros del problema
# -----------------------------
x_real = 10
sigma_ruido = 0.5

N_values = [10, 20, 50, 100, 200, 500, 1000]

promedios = []
desviaciones = []

# -----------------------------
# Simulación para varios N
# -----------------------------
for N in N_values:

    mediciones = x_real + np.random.normal(0, sigma_ruido, N)

    promedio = np.mean(mediciones)
    sigma = np.std(mediciones, ddof=1)

    promedios.append(promedio)
    desviaciones.append(sigma)

    print("N =", N)
    print("Promedio =", promedio)
    print("Desviación estándar =", sigma)
    print("---------------------------")

# -----------------------------
# Gráfica de la desviación estimada
# -----------------------------
plt.figure(figsize=(8,5))

plt.plot(N_values, desviaciones, 'o-')

plt.xlabel("Número de mediciones N")
plt.ylabel("Desviación estándar estimada")
plt.title("Estimación de la incertidumbre en función del número de mediciones")

# -----------------------------
# Guardar figura
# -----------------------------
plt.savefig("Actividad_6_1_incertidumbre.pdf", dpi=300, bbox_inches="tight")

plt.show()

# -----------------------------
# Descargar automáticamente
# -----------------------------
files.download("Actividad_6_1_incertidumbre.pdf")
# Out:
# N = 10
# Promedio = 10.115141038920555
# Desviación estándar = 0.32214672146206563
# ---------------------------
# N = 20
# Promedio = 9.760343744650395
# Desviación estándar = 0.36104235270855367
# ---------------------------
# N = 50
# Promedio = 9.891885548062875
# Desviación estándar = 0.50038476610106
# ---------------------------
# N = 100
# Promedio = 10.010235983480788
# Desviación estándar = 0.4988992359826917
# ---------------------------
# N = 200
# Promedio = 9.95909791357746
# Desviación estándar = 0.5064662905249618
# ---------------------------
# N = 500
# Promedio = 10.00085459550556
# Desviación estándar = 0.4975893680990944
# ---------------------------
# N = 1000
# Promedio = 10.006916839250005
# Desviación estándar = 0.489872491662861
# ---------------------------
